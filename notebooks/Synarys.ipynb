# %% [markdown]
# # ⚙️ Preprocessing

# %%
# Imports principaux
import pandas as pd
import numpy as np

# %%
freelance_df = pd.read_csv('../generate_datasets/freelances_dataset.csv', index_col='freelance_id').reset_index(drop=True)
prospect_df = pd.read_csv('../generate_datasets/prospects_dataset.csv', index_col='prospect_id').reset_index(drop=True)
freelance_df
# Out:
#                   name                       title main_sector  \
# 0         Norma Fisher     Sustainable Engineering   GreenTech
# 1         Heather Snow             Risk Management     FinTech
# 2    Danielle Browning  Health & Wellness Coaching    Wellness
# 3       Brian Hamilton             Risk Management     FinTech
# 4       Kimberly Smith  Renewable Energy Expertise   GreenTech
# ..                 ...                         ...         ...
# 295      Kevin Pearson        Software Development   Tech/SaaS
# 296       Nicholas Lee         Nutrition Expertise    Wellness
# 297     Hailey Huffman              Brand Strategy   Marketing
# 298         Luis Black        Software Development   Tech/SaaS
# 299      Barbara Nunez       Regulatory Compliance     FinTech
#
#                                            top3_skills          city  \
# 0                              LCA|IoT|Energy Modeling     Tammyfort
# 1                            Risk Modeling|AML/KYC|SQL    New Donald
# 2                    Yoga|Community Management|Pilates    West Corey
# 3                               Python|PowerBI|AML/KYC    New Thomas
# 4    Project Management|Energy Modeling|Carbon Acco...      Pagetown
# ..                                                 ...           ...
# 295                                  Python|AWS|Docker   Lake Monica
# 296                      Nutrition|Copywriting|Pilates    Lake Casey
# 297                          SEO|Analytics|Copywriting      Dunnside
# 298                                 Python|AWS|FastAPI  Clarkborough
# 299                          AML/KYC|Risk Modeling|SQL   North James
#
#      daily_rate                                  mission_statement  \
# 0        640.15  Norma Fisher drives inspiring eco-solutions us...
# 1        829.06  Partner with Heather Snow for analytical Risk ...
# 2        691.87  Danielle Browning promotes vibrant wellness wi...
# 3        482.34  Brian Hamilton empowers focused FinTech ventur...
# 4        470.74  Partner with Kimberly Smith for dynamic Projec...
# ..          ...                                                ...
# 295      834.04  With Kevin Pearson, secure expertise in Python...
# 296      454.27  Nicholas Lee promotes exclusive wellness with ...
# 297      871.68  Hailey Huffman transforms marketing with trust...
# 298      871.04  Partner with Luis Black for forward-thinking P...
# 299      713.26  Partner with Barbara Nunez for trustworthy AML...
#
#     preferred_tone preferred_style remote  \
# 0        Energetic            Warm     No
# 1          Serious            Warm    Yes
# 2        Energetic            Warm     No
# 3          Serious          Formal    Yes
# 4        Energetic    Storytelling    Yes
# ..             ...             ...    ...
# 295        Serious    Storytelling     No
# 296        Premium          Formal    Yes
# 297   Professional    Storytelling    Yes
# 298       Creative    Storytelling    Yes
# 299       Friendly          Formal    Yes
#
#                                        email
# 0        norma.fisher@greentechfreelance.com
# 1          heather.snow@fintechfreelance.com
# 2    danielle.browning@wellnessfreelance.com
# 3        brian.hamilton@fintechfreelance.com
# 4      kimberly.smith@greentechfreelance.com
# ..                                       ...
# 295      kevin.pearson@techsaasfreelance.com
# 296       nicholas.lee@wellnessfreelance.com
# 297    hailey.huffman@marketingfreelance.com
# 298         luis.black@techsaasfreelance.com
# 299       barbara.nunez@fintechfreelance.com
#
# [300 rows x 11 columns]

# %%
import string
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character for WordNetLemmatizer"""
    tag = pos_tag([word])[0][1][0].lower()  # Get first letter of POS tag
    return{'n': 'n', 'v': 'v', 'a': 'a', 'r': 'r'}.get(tag, 'n')

def cleaning(sentence):
    # Basic cleaning
    sentence = sentence.strip().lower()
    sentence = ''.join(char for char in sentence if not char.isdigit())
    sentence = sentence.translate(str.maketrans('', '', string.punctuation))

    # Tokenization
    tokenized_sentence = word_tokenize(sentence)

    # Stopwords removal
    stop_words = set(stopwords.words('english'))
    tokenized_sentence_cleaned = [w for w in tokenized_sentence if w not in stop_words]

    # Lemmatization with correct POS tagging
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in tokenized_sentence_cleaned]

    return ' '.join(lemmatized)

# %%
freelance_df['tfidf_vector'] = freelance_df['mission_statement'].apply(cleaning)
prospect_df['tfidf_vector'] = prospect_df['mission_statement'].apply(cleaning)
freelance_df
# Out:
#                   name                       title main_sector  \
# 0         Norma Fisher     Sustainable Engineering   GreenTech
# 1         Heather Snow             Risk Management     FinTech
# 2    Danielle Browning  Health & Wellness Coaching    Wellness
# 3       Brian Hamilton             Risk Management     FinTech
# 4       Kimberly Smith  Renewable Energy Expertise   GreenTech
# ..                 ...                         ...         ...
# 295      Kevin Pearson        Software Development   Tech/SaaS
# 296       Nicholas Lee         Nutrition Expertise    Wellness
# 297     Hailey Huffman              Brand Strategy   Marketing
# 298         Luis Black        Software Development   Tech/SaaS
# 299      Barbara Nunez       Regulatory Compliance     FinTech
#
#                                            top3_skills          city  \
# 0                              LCA|IoT|Energy Modeling     Tammyfort
# 1                            Risk Modeling|AML/KYC|SQL    New Donald
# 2                    Yoga|Community Management|Pilates    West Corey
# 3                               Python|PowerBI|AML/KYC    New Thomas
# 4    Project Management|Energy Modeling|Carbon Acco...      Pagetown
# ..                                                 ...           ...
# 295                                  Python|AWS|Docker   Lake Monica
# 296                      Nutrition|Copywriting|Pilates    Lake Casey
# 297                          SEO|Analytics|Copywriting      Dunnside
# 298                                 Python|AWS|FastAPI  Clarkborough
# 299                          AML/KYC|Risk Modeling|SQL   North James
#
#      daily_rate                                  mission_statement  \
# 0        640.15  Norma Fisher drives inspiring eco-solutions us...
# 1        829.06  Partner with Heather Snow for analytical Risk ...
# 2        691.87  Danielle Browning promotes vibrant wellness wi...
# 3        482.34  Brian Hamilton empowers focused FinTech ventur...
# 4        470.74  Partner with Kimberly Smith for dynamic Projec...
# ..          ...                                                ...
# 295      834.04  With Kevin Pearson, secure expertise in Python...
# 296      454.27  Nicholas Lee promotes exclusive wellness with ...
# 297      871.68  Hailey Huffman transforms marketing with trust...
# 298      871.04  Partner with Luis Black for forward-thinking P...
# 299      713.26  Partner with Barbara Nunez for trustworthy AML...
#
#     preferred_tone preferred_style remote  \
# 0        Energetic            Warm     No
# 1          Serious            Warm    Yes
# 2        Energetic            Warm     No
# 3          Serious          Formal    Yes
# 4        Energetic    Storytelling    Yes
# ..             ...             ...    ...
# 295        Serious    Storytelling     No
# 296        Premium          Formal    Yes
# 297   Professional    Storytelling    Yes
# 298       Creative    Storytelling    Yes
# 299       Friendly          Formal    Yes
#
#                                        email  \
# 0        norma.fisher@greentechfreelance.com
# 1          heather.snow@fintechfreelance.com
# 2    danielle.browning@wellnessfreelance.com
# 3        brian.hamilton@fintechfreelance.com
# 4      kimberly.smith@greentechfreelance.com
# ..                                       ...
# 295      kevin.pearson@techsaasfreelance.com
# 296       nicholas.lee@wellnessfreelance.com
# 297    hailey.huffman@marketingfreelance.com
# 298         luis.black@techsaasfreelance.com
# 299       barbara.nunez@fintechfreelance.com
#
#                                           tfidf_vector
# 0    norma fisher drive inspire ecosolutions use lc...
# 1    partner heather snow analytical risk model aml...
# 2    danielle browning promotes vibrant wellness yo...
# 3    brian hamilton empowers focus fintech venture ...
# 4    partner kimberly smith dynamic project managem...
# ..                                                 ...
# 295  kevin pearson secure expertise python aws scal...
# 296  nicholas lee promotes exclusive wellness nutri...
# 297  hailey huffman transforms marketing trust seo ...
# 298  partner luis black forwardthinking python aws ...
# 299  partner barbara nunez trustworthy amlkyc risk ...
#
# [300 rows x 12 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import vstack

# %%
def vectorize_missions(freelance_df, prospect_df):
    """
    Vectorise les mission statements avec TF-IDF et stocke les vecteurs dans la colonne 'tfidf_vector'.
    """
    # Copie des textes bruts
    all_missions = pd.concat([
        freelance_df["tfidf_vector"],
        prospect_df["tfidf_vector"]
    ])

    vectorizer = TfidfVectorizer(stop_words='english')
    vectorizer.fit(all_missions)

    # Ajoute les vecteurs TF-IDF dans une nouvelle colonne
    freelance_df = freelance_df.copy()
    prospect_df = prospect_df.copy()

    freelance_df["tfidf_vector"] = list(vectorizer.transform(freelance_df["tfidf_vector"]))
    prospect_df["tfidf_vector"] = list(vectorizer.transform(prospect_df["tfidf_vector"]))
    return freelance_df, prospect_df

freelance_df, prospect_df = vectorize_missions(freelance_df, prospect_df)

# %% [markdown]
# # 💞 Matching

# %%
def get_top_20_leads(freelance_vec, prospect_df):
    """
    Retourne les 20 prospects les plus proches du vecteur freelance donné.
    """
    prospect_matrix = vstack(prospect_df["tfidf_vector"].values)

    similarities = cosine_similarity(freelance_vec, prospect_matrix).flatten()
    top_20_idx = similarities.argsort()[-20:][::-1]

    return prospect_df.iloc[top_20_idx].assign(similarity=similarities[top_20_idx])

top_20_df = get_top_20_leads(freelance_df.iloc[0]["tfidf_vector"], prospect_df)
top_20_df
# Out:
#                           company     sector       main_contact  \
# 1160            Anderson and Sons  GreenTech     Michelle Woods
# 2616        Carr, Zhang and Green  GreenTech  Kimberly Williams
# 2720                 Byrd-Pearson  GreenTech       Lauren Boyle
# 2895           Cox, Webb and Chan  GreenTech      Michael Brown
# 1194                   Farmer PLC  GreenTech        Hannah King
# 433     Dudley, Gross and Gregory  GreenTech   Amanda Hernandez
# 1424                    Lee Group  GreenTech       Lisa Edwards
# 1578             Stanley and Sons  GreenTech        Katie Booth
# 652                 White-Simmons  GreenTech     Matthew Snyder
# 2835                Snow-Mitchell  GreenTech       Susan Martin
# 1063       Hogan, Moore and Patel  GreenTech       Misty Rivera
# 404                    Butler PLC  GreenTech  Whitney Armstrong
# 2989                      Lee Inc  GreenTech       Julia Moreno
# 237    Navarro, Sexton and Walker  GreenTech     Timothy Harris
# 1439                   Tucker Inc  GreenTech     Cynthia Mathis
# 596   Gomez, Thompson and Johnson  GreenTech     Peter Callahan
# 2272   Gonzalez, Guzman and Walsh  GreenTech          Adam Diaz
# 2167                   Ford Group  GreenTech          Gina Lane
# 773               Richardson-Cain  GreenTech      Cameron Jones
# 1911                  Meyer Group  GreenTech        Autumn Holt
#
#            contact_role                city  \
# 1160       Head of Data             Kimtown
# 2616       Head of Data           Port Beth
# 2720       Head of Data         Taraborough
# 2895                CTO           Debratown
# 1194                CTO         West Daniel
# 433   Head of Marketing         South Karen
# 1424                CEO          Thomasstad
# 1578                CEO    Port Eileenshire
# 652        Head of Data   Lake Anthonyshire
# 2835                CTO  North Mitchellbury
# 1063       Head of Data       North Brandon
# 404                 CTO           Haysmouth
# 2989                CTO          West Donna
# 237                 CEO       Stevensonbury
# 1439                CEO    West Robertmouth
# 596                 CTO    Christophermouth
# 2272  Head of Marketing            Johntown
# 2167  Head of Marketing          Fowlertown
# 773                 CTO      North Veronica
# 1911       Head of Data      Elizabethville
#
#                                       mission_statement         company_size  \
# 1160  Empowering enterprise to accelerate sustainabi...   Enterprise (1000+)
# 2616  Our eco-friendly solutions help startup accele...       Startup (1-20)
# 2720  Our eco-friendly solutions help enterprise acc...   Enterprise (1000+)
# 2895  Our eco-friendly solutions help enterprise acc...   Enterprise (1000+)
# 1194  Our eco-friendly solutions help enterprise acc...   Enterprise (1000+)
# 433   We support startup in accelerate sustainabilit...       Startup (1-20)
# 1424  Empowering startup to transform sustainability...       Startup (1-20)
# 1578  Empowering mid-size to transform sustainabilit...  Mid-size (201-1000)
# 652   At the intersection of ecology and innovation,...       Startup (1-20)
# 2835  At the intersection of ecology and innovation,...   Enterprise (1000+)
# 1063  Empowering sme to accelerate sustainability su...         SME (21-200)
# 404   Empowering enterprise to accelerate sustainabi...   Enterprise (1000+)
# 2989  Empowering sme to accelerate sustainability su...         SME (21-200)
# 237   We support mid-size in pioneer green value cha...  Mid-size (201-1000)
# 1439  At the intersection of ecology and innovation,...         SME (21-200)
# 596   Empowering mid-size to reduce carbon footprint...  Mid-size (201-1000)
# 2272  Our eco-friendly solutions help sme enhance en...         SME (21-200)
# 2167  Our eco-friendly solutions help startup enhanc...       Startup (1-20)
# 773   Empowering startup to accelerate sustainabilit...       Startup (1-20)
# 1911  Our eco-friendly solutions help enterprise enh...   Enterprise (1000+)
#
#      funding_stage ticket_size_class   target_tone remote  \
# 1160      Pre-Seed              High  Professional     No
# 2616      Series A            Medium      Friendly     No
# 2720          Seed              High  Professional     No
# 2895      Series A              High  Professional     No
# 1194      Series A              High     Energetic    Yes
# 433      Series C+              High       Premium     No
# 1424      Series A            Medium      Creative    Yes
# 1578      Series A            Medium      Creative    Yes
# 652       Series B              High      Friendly    Yes
# 2835      Series A              High     Energetic    Yes
# 1063      Series A            Medium       Serious    Yes
# 404       Pre-Seed              High       Serious     No
# 2989      Series A            Medium       Serious     No
# 237       Series A            Medium      Friendly     No
# 1439      Series B              High  Professional     No
# 596       Series B              High       Serious    Yes
# 2272      Series B              High      Creative    Yes
# 2167     Series C+              High      Creative    Yes
# 773       Pre-Seed               Low  Professional    Yes
# 1911      Series B              High      Creative     No
#
#                                            email  \
# 1160          michelle.woods@andersonandsons.com
# 2616     kimberly.williams@carrzhangandgreen.com
# 2720                lauren.boyle@byrdpearson.com
# 2895            michael.brown@coxwebbandchan.com
# 1194                   hannah.king@farmerplc.com
# 433   amanda.hernandez@dudleygrossandgregory.com
# 1424                   lisa.edwards@leegroup.com
# 1578              katie.booth@stanleyandsons.com
# 652              matthew.snyder@whitesimmons.com
# 2835               susan.martin@snowmitchell.com
# 1063         misty.rivera@hoganmooreandpatel.com
# 404              whitney.armstrong@butlerplc.com
# 2989                     julia.moreno@leeinc.com
# 237    timothy.harris@navarrosextonandwalker.com
# 1439                cynthia.mathis@tuckerinc.com
# 596   peter.callahan@gomezthompsonandjohnson.com
# 2272        adam.diaz@gonzalezguzmanandwalsh.com
# 2167                     gina.lane@fordgroup.com
# 773             cameron.jones@richardsoncain.com
# 1911                  autumn.holt@meyergroup.com
#
#                                            tfidf_vector  similarity
# 1160  <Compressed Sparse Row sparse matrix of dtype ...    0.206394
# 2616  <Compressed Sparse Row sparse matrix of dtype ...    0.173981
# 2720  <Compressed Sparse Row sparse matrix of dtype ...    0.173892
# 2895  <Compressed Sparse Row sparse matrix of dtype ...    0.171224
# 1194  <Compressed Sparse Row sparse matrix of dtype ...    0.171224
# 433   <Compressed Sparse Row sparse matrix of dtype ...    0.162528
# 1424  <Compressed Sparse Row sparse matrix of dtype ...    0.162043
# 1578  <Compressed Sparse Row sparse matrix of dtype ...    0.158649
# 652   <Compressed Sparse Row sparse matrix of dtype ...    0.157608
# 2835  <Compressed Sparse Row sparse matrix of dtype ...    0.155492
# 1063  <Compressed Sparse Row sparse matrix of dtype ...    0.148496
# 404   <Compressed Sparse Row sparse matrix of dtype ...    0.147319
# 2989  <Compressed Sparse Row sparse matrix of dtype ...    0.146657
# 237   <Compressed Sparse Row sparse matrix of dtype ...    0.146114
# 1439  <Compressed Sparse Row sparse matrix of dtype ...    0.144798
# 596   <Compressed Sparse Row sparse matrix of dtype ...    0.144020
# 2272  <Compressed Sparse Row sparse matrix of dtype ...    0.142365
# 2167  <Compressed Sparse Row sparse matrix of dtype ...    0.142346
# 773   <Compressed Sparse Row sparse matrix of dtype ...    0.142139
# 1911  <Compressed Sparse Row sparse matrix of dtype ...    0.141630

# %% [markdown]
# # 📧 Mail generator

# %%
from langchain.chat_models import init_chat_model
from IPython.display import Markdown
import time

# %%
def mail_generator(freelance, prospect):
    """
    Génère un email de prospection personnalisé en anglais à partir des données d’un freelance et d’une entreprise cible.

    Paramètres :
    -----------
    freelance : dict
        Dictionnaire contenant les informations du freelance :
        - 'name' : Nom complet
        - 'title' : Titre ou métier
        - 'main_sector' : Secteur principal d’activité
        - 'city' : Ville
        - 'top3_skills' : Compétences clés (format texte)
        - 'daily_rate' : Tarif journalier
        - 'remote' : "Yes"/"No"
        - 'mission_statement' : Résumé de la proposition de valeur
        - 'preferred_tone' : Ton préféré (ex. : Professional)
        - 'preferred_style' : Style préféré (ex. : Storytelling)

    prospect : pandas.Series ou dict
        Informations sur l’entreprise cible :
        - 'company' : Nom de l’entreprise
        - 'city' : Ville
        - 'sector' : Secteur d’activité
        - 'main_contact' : Nom du contact principal
        - 'contact_role' : Poste du contact
        - 'company_size' : Taille de l’entreprise
        - 'funding_stage' : Stade de financement
        - 'remote' : "Yes"/"No"
        - 'target_tone' : Ton attendu côté entreprise

    Retour :
    --------
    prospect : pandas.Series ou dict
        Le même objet que `prospect` mais avec un champ supplémentaire 'mail' contenant l’email généré.
    """

    model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")
    prospect = prospect.copy()

    prompt = f"""
    Write a clear, professional, and personalized cold email in English, addressed to {prospect['main_contact']} ({prospect['contact_role']})
    from the company {prospect['company']}, based in {prospect['city']} and operating in the {prospect['sector']} sector.

    You are {freelance['name']}, a {freelance['title']} based in {freelance['city']}, specialized in the {freelance['main_sector']} sector.
    You provide services with expertise in {freelance['top3_skills']}, at a daily rate of {freelance['daily_rate']} EUR (remote: {freelance['remote']}).
    Your mission is: {freelance['mission_statement']}

    The company is a {prospect['company_size']} at the {prospect['funding_stage']} stage, and remote work availability is {prospect['remote']}.

    The email should:
    - Open with a brief and relevant introduction.
    - Present the value you can bring to this company in 2–3 concise sentences.
    - Match the company's tone: {prospect['target_tone']}, while reflecting your preferred tone: {freelance['preferred_tone']} and style: {freelance['preferred_style']}.
    - Be business-oriented and adapted to the company's context.
    - End with a clear, actionable closing (e.g., propose a short call or ask for availability).
    - Sign with your name
    Ensure the language is polite, direct, and free from repetition or generic phrases. Avoid using placeholders or uncertain formulations.
    Return only the body of the email ready to be sent (no subject line or explanation).
    """

    try:
        response = model.invoke(prompt)
        content = response.content if hasattr(response, "content") else str(response)
    except Exception as e:
        print(f"Error : {e}")
        content = f"ERROR: {e}"

    content = response.__dict__['content']

    return content

# %%
freelance_index = 2
freelance = freelance_df.iloc[freelance_index]
top_20_df = get_top_20_leads(freelance_df.iloc[freelance_index]["tfidf_vector"], prospect_df)
prospect = top_20_df.iloc[4]

Markdown(mail_generator(freelance, prospect))
# Out:
# Dear Aaron,
#
# I'm Danielle Browning, a Health & Wellness Coach based in West Corey, specializing in the Wellness sector, and I was particularly interested in Erickson, Johnson and Gonzalez's innovative work in Stevenland.
#
# With my expertise in Yoga, Pilates, and Community Management, I can help Erickson, Johnson and Gonzalez foster a thriving and engaged employee community, boosting morale and promoting overall well-being. My tailored strategies can directly contribute to a healthier and more productive workforce, aligning perfectly with your company's focus on wellness.
#
# Would you be open to a brief 15-minute call next week to discuss how I can contribute to Erickson, Johnson and Gonzalez's wellness initiatives?
#
# Sincerely,
#
# Danielle Browning
