# %% [markdown]
# # 💞 Vectorisation & Matching

# %%
# Imports principaux
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
freelance_df = pd.read_csv('../generate_datasets/updated_freelances_dataset.csv', index_col='freelance_id').reset_index(drop=True)
prospect_df = pd.read_csv('../generate_datasets/updated_prospects_dataset.csv', index_col='prospect_id').reset_index(drop=True)
freelance_df
# Out:
#                 name                          title        main_sector  \
# 0       Allison Hill              Digital Marketing          Marketing
# 1     Javier Johnson     Renewable Energy Expertise          GreenTech
# 2    Meredith Barnes  Environmental Impact Analysis          GreenTech
# 3       Donald Lewis        Supply Chain Management  Retail/E-commerce
# 4        Renee Blair               Customer Service  Retail/E-commerce
# ..               ...                            ...                ...
# 295     Tracy Rivera             Project Management          GreenTech
# 296    Kristin Watts            Ed-Tech Integration  Education/Ed-Tech
# 297   Kathryn Cooper               Customer Service  Retail/E-commerce
# 298      Eric Gibson           Community Management           Wellness
# 299       Jodi Jones            Ed-Tech Integration  Education/Ed-Tech
#
#                                       top3_skills                 city  \
# 0                        Analytics|Google Ads|SEO            East Jill
# 1          LCA|Project Management|Energy Modeling         East William
# 2                         Energy Modeling|IoT|LCA         Lawrencetown
# 3    Facebook Ads|Customer Support|Data Analytics           Curtisfurt
# 4           Supply-Chain|Shopify|Customer Support  South Christianport
# ..                                            ...                  ...
# 295         Energy Modeling|IoT|Carbon Accounting       Rodriguezville
# 296         Learning Analytics|Storyline360|HTML5           South Neil
# 297      Data Analytics|Supply-Chain|Facebook Ads     South Danchester
# 298                 Copywriting|Pilates|Nutrition          New Timothy
# 299        Storyline360|Python|Learning Analytics    Port Jennifertown
#
#      daily_rate                                  mission_statement  \
# 0        397.68  Allison Hill delivers trusted solutions in Ana...
# 1        462.86  Javier Johnson advances focused sustainability...
# 2        831.17  With Meredith Barnes, effective expertise in E...
# 3        371.55  Donald Lewis excels in visionary Facebook Ads ...
# 4        621.60  Renee Blair excels in trusted Supply-Chain and...
# ..          ...                                                ...
# 295      847.87  With Tracy Rivera, dynamic expertise in Energy...
# 296      374.88  With Kristin Watts, passionate expertise in Le...
# 297      534.32  Kathryn Cooper excels in high-quality Data Ana...
# 298      519.93  Eric Gibson excels in visionary Copywriting an...
# 299      496.21  With Jodi Jones, creative expertise in Storyli...
#
#     preferred_tone preferred_style remote
# 0     Professional    Storytelling    Yes
# 1          Serious          Formal    Yes
# 2         Friendly    Storytelling     No
# 3         Creative          Formal     No
# 4     Professional            Warm    Yes
# ..             ...             ...    ...
# 295      Energetic            Warm    Yes
# 296      Energetic          Formal     No
# 297        Premium    Storytelling    Yes
# 298       Creative            Warm     No
# 299       Creative            Warm    Yes
#
# [300 rows x 10 columns]

# %%
prospect_df
# Out:
#                             company             sector      main_contact  \
# 0            Marsh, Spears and Yang            FinTech    Kristen Rivera
# 1                         Lopez Ltd            FinTech      Allen Mendez
# 2                       Ramirez Ltd             Design        Amy Garcia
# 3          Huffman, Rose and Fowler          GreenTech     Lisa Matthews
# 4     Mcbride, Sellers and Lawrence          GreenTech       Emily Allen
# ...                             ...                ...               ...
# 2995                       Hill PLC  Retail/E-commerce       Amanda Bird
# 2996       Mendoza, Hayes and Lynch  Retail/E-commerce  Timothy Alvarado
# 2997   Carpenter, Nielsen and Stone          Tech/SaaS  Elaine Rodriguez
# 2998                      Wells Ltd          Marketing       Renee Hurst
# 2999        Garcia, Flores and Ford  Education/Ed-Tech       David Hines
#
#            contact_role                city  \
# 0                   CEO          Mullenbury
# 1                   CEO      South Brittany
# 2     Head of Marketing           West Mark
# 3          Head of Data        Michaelmouth
# 4                   CEO  East Nathanielberg
# ...                 ...                 ...
# 2995                CEO        Fergusonport
# 2996                CEO          Andrewfort
# 2997                CTO          Burchmouth
# 2998                CTO         Stanleyland
# 2999       Head of Data   North Josephmouth
#
#                                       mission_statement         company_size  \
# 0     Delivering high-quality financial platforms, d...         SME (21-200)
# 1     Delivering effective financial platforms, pion...   Enterprise (1000+)
# 2     Crafting high-quality designs to revolutionize...  Mid-size (201-1000)
# 3     Advancing effective green technologies to inno...   Enterprise (1000+)
# 4     Advancing effective green technologies to pion...   Enterprise (1000+)
# ...                                                 ...                  ...
# 2995  Providing effective e-commerce solutions to dr...       Startup (1-20)
# 2996  Providing effective e-commerce solutions to dr...  Mid-size (201-1000)
# 2997  Empowering premium digital transformation, enh...         SME (21-200)
# 2998  Delivering high-quality marketing strategies t...       Startup (1-20)
# 2999  Delivering effective financial platforms, empo...   Enterprise (1000+)
#
#      funding_stage ticket_size_class target_tone remote
# 0        Series C+              High     Premium     No
# 1         Series A              High    Creative     No
# 2             Seed            Medium     Premium    Yes
# 3         Pre-Seed              High     Serious     No
# 4        Series C+              High   Energetic    Yes
# ...            ...               ...         ...    ...
# 2995      Series B              High    Friendly     No
# 2996          Seed            Medium    Friendly    Yes
# 2997      Series B              High     Premium    Yes
# 2998      Series B              High     Premium    Yes
# 2999          Seed              High   Energetic    Yes
#
# [3000 rows x 11 columns]

# %%
def vectorize_missions(freelance_df, prospect_df):
    """Vectorise les mission statements des freelances et prospects avec TF-IDF."""
    vectorizer = TfidfVectorizer(stop_words='english')
    freelance_tfidf = vectorizer.fit_transform(freelance_df["mission_statement"])
    prospect_tfidf = vectorizer.transform(prospect_df["mission_statement"])
    return freelance_tfidf, prospect_tfidf

def get_top_20_leads(freelance_vec, prospect_tfidf, prospect_df):
    """
    Retourne les 20 prospects les plus similaires pour un vecteur freelance donné.

    Args:
        freelance_vec: Vecteur TF-IDF (1D ou 2D) du freelance (shape: (1, n_features)).
        prospect_tfidf: Matrice TF-IDF des prospects.
        prospect_df: DataFrame des prospects.

    Returns:
        DataFrame des 20 prospects les plus similaires avec score de similarité.
    """
    similarities = cosine_similarity(freelance_vec, prospect_tfidf).flatten()
    top_20_indices = similarities.argsort()[-20:][::-1]

    return prospect_df.iloc[top_20_indices].assign(
        similarity=similarities[top_20_indices]
    )

# %%
freelance_tfidf, prospect_tfidf = vectorize_missions(freelance_df, prospect_df)
top_20_df = get_top_20_leads(freelance_tfidf[0], prospect_tfidf, prospect_df)

# %%
top_20_df
# Out:
#                                company             sector      main_contact  \
# 1161         Spencer, Jones and Miller          Tech/SaaS       Mark Romero
# 2414      Joseph, Campbell and Douglas          Tech/SaaS     Tristan Rojas
# 1730                       Perez-Smith          Tech/SaaS    Catherine Cole
# 934                       Thomas Group          Tech/SaaS  Alexander Taylor
# 510                   Rogers-Maldonado          Tech/SaaS       Ethan Allen
# 46                    Ramirez and Sons          Tech/SaaS     Marvin Robles
# 144                       Cortez-Olson          Marketing     Daniel Martin
# 843            Bennett, George and Fox          Marketing     Adrian Prince
# 1782                        Lin-Mendez          Marketing         Mark Hill
# 2451         Hayes, Elliott and George          Marketing     Michael Smith
# 1251          Medina, Wise and Aguirre          Marketing    Ernest Jenkins
# 1646                      Short-Parker          Tech/SaaS      Jared Carter
# 1581        Warren, Flowers and Ingram          Tech/SaaS    Kenneth Harmon
# 2345     Sanchez, Higgins and Caldwell          Tech/SaaS      Thomas Jones
# 1541      Mcintyre, Molina and Collins          Tech/SaaS      Tracy Torres
# 485                    Brooks and Sons          Tech/SaaS      Alan Johnson
# 1928                       Moyer-Patel          Tech/SaaS    Thomas Sellers
# 1231                      Miller Group          Tech/SaaS     Monica Medina
# 2108                      Rhodes-Gomez  Retail/E-commerce     Jeffrey Cooke
# 2348  Christensen, Vasquez and Herrera  Retail/E-commerce     Candice Evans
#
#       contact_role                city  \
# 1161  Head of Data      Lake Dianaland
# 2414  Head of Data       North Melissa
# 1730  Head of Data          East Renee
# 934   Head of Data         Patrickberg
# 510   Head of Data       Elizabethfurt
# 46    Head of Data       Lake Virginia
# 144   Head of Data          Johnsonton
# 843   Head of Data  South Vanessaville
# 1782  Head of Data        Martinezport
# 2451  Head of Data       New Davidtown
# 1251  Head of Data        North Xavier
# 1646           CTO  East Jennifershire
# 1581           CTO        Caitlynmouth
# 2345           CTO          Robertfurt
# 1541           CTO        East Tiffany
# 485            CTO       West Loriland
# 1928           CTO          Davidmouth
# 1231           CTO          Sarahhaven
# 2108  Head of Data         Natashastad
# 2348  Head of Data          Robertland
#
#                                       mission_statement         company_size  \
# 1161  Empowering effective digital transformation, i...         SME (21-200)
# 2414  Empowering effective digital transformation, i...  Mid-size (201-1000)
# 1730  Empowering effective digital transformation, i...   Enterprise (1000+)
# 934   Empowering effective digital transformation, i...         SME (21-200)
# 510   Empowering effective digital transformation, i...       Startup (1-20)
# 46    Empowering effective digital transformation, i...       Startup (1-20)
# 144   Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 843   Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 1782  Delivering effective marketing strategies to i...         SME (21-200)
# 2451  Delivering effective marketing strategies to i...         SME (21-200)
# 1251  Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 1646  Empowering effective digital transformation, i...  Mid-size (201-1000)
# 1581  Empowering effective digital transformation, i...       Startup (1-20)
# 2345  Empowering effective digital transformation, i...       Startup (1-20)
# 1541  Empowering effective digital transformation, i...   Enterprise (1000+)
# 485   Empowering effective digital transformation, i...       Startup (1-20)
# 1928  Empowering effective digital transformation, i...   Enterprise (1000+)
# 1231  Empowering effective digital transformation, i...   Enterprise (1000+)
# 2108  Providing effective e-commerce solutions to in...   Enterprise (1000+)
# 2348  Providing effective e-commerce solutions to in...       Startup (1-20)
#
#      funding_stage ticket_size_class   target_tone remote  similarity
# 1161          Seed            Medium       Serious     No    0.310670
# 2414          Seed            Medium      Creative    Yes    0.310670
# 1730      Series B              High  Professional     No    0.310670
# 934           Seed            Medium       Serious    Yes    0.310670
# 510       Series A            Medium  Professional    Yes    0.310670
# 46            Seed               Low      Creative    Yes    0.310670
# 144      Series C+              High       Serious    Yes    0.276999
# 843       Series A            Medium      Friendly     No    0.276999
# 1782      Series A            Medium      Creative    Yes    0.276999
# 2451      Series B              High  Professional    Yes    0.276999
# 1251      Series B              High       Serious    Yes    0.276999
# 1646     Series C+              High      Friendly     No    0.276390
# 1581     Series C+              High      Creative    Yes    0.276390
# 2345      Series B              High  Professional    Yes    0.276390
# 1541     Series C+              High  Professional     No    0.276390
# 485       Series B              High      Friendly     No    0.276390
# 1928      Series B              High     Energetic     No    0.276390
# 1231          Seed              High       Serious    Yes    0.276390
# 2108      Series B              High  Professional     No    0.267038
# 2348      Series B              High      Friendly    Yes    0.267038

# %% [markdown]
# # 📧 Mail generator

# %%
from langchain.chat_models import init_chat_model
from IPython.display import Markdown
import time

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
freelance = freelance_df.iloc[0]
freelance
# Out:
# name                                                      Allison Hill
# title                                                Digital Marketing
# main_sector                                                  Marketing
# top3_skills                                   Analytics|Google Ads|SEO
# city                                                         East Jill
# daily_rate                                                      397.68
# mission_statement    Allison Hill delivers trusted solutions in Ana...
# preferred_tone                                            Professional
# preferred_style                                           Storytelling
# remote                                                             Yes
# Name: 0, dtype: object

# %%
prospect = top_20_df.iloc[0]
prospect
# Out:
# company                                      Spencer, Jones and Miller
# sector                                                       Tech/SaaS
# main_contact                                               Mark Romero
# contact_role                                              Head of Data
# city                                                    Lake Dianaland
# mission_statement    Empowering effective digital transformation, i...
# company_size                                              SME (21-200)
# funding_stage                                                     Seed
# ticket_size_class                                               Medium
# target_tone                                                    Serious
# remote                                                              No
# similarity                                                     0.31067
# Name: 1161, dtype: object

# %%
prompt = f"""
Write a concise and professional cold email in English to offer your mission: {freelance['mission_statement']}
to a company called {prospect['company']} based in {prospect['city']}, operating in the {prospect['sector']} sector.
Your contact is {prospect['main_contact']}, who is the {prospect['contact_role']}.

You are {freelance['name']}, a {freelance['title']} specialized in the {freelance['main_sector']} sector,
based in {freelance['city']}. You offer services with top skills in {freelance['top3_skills']},
at a daily rate of {freelance['daily_rate']} (remote: {freelance['remote']}).

Highlight your main value proposition in 2–3 sentences, adapted to the needs of a company like {prospect['company']}
(size: {prospect['company_size']}, funding stage: {prospect['funding_stage']}, remote work: {prospect['remote']}).

Include a clear call to action. Keep the tone {freelance['preferred_tone']} and the style {freelance['preferred_style']},
while matching the company’s target tone: {prospect['target_tone']}.
"""

# %%
response = model.invoke(prompt)
Markdown(response.__dict__['content'])
# Out:
# Subject: Innovating Spencer, Jones and Miller's Marketing with Data-Driven Growth
#
# Dear Mark Romero,
#
# My name is Allison Hill, and I'm a digital marketing specialist based in East Jill. I help companies like yours in the Tech/SaaS sector unlock significant growth through data-driven strategies in Analytics and Google Ads.
#
# At Spencer, Jones and Miller, I imagine you're constantly seeking ways to optimize your marketing spend and refine your customer acquisition efforts. I specialize in creating tailored strategies that provide actionable insights and scalable, user-focused campaigns, helping SMEs like yours achieve impactful business success.
#
# Would you be open to a brief 15-minute call next week to discuss how I can help Spencer, Jones and Miller leverage the power of analytics to drive more qualified leads and improve your ROI?
#
# Sincerely,
#
# Allison Hill
# [Your Contact Information]

# %%
def mail_generator(freelance, top_20_df):
    model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

    top_20_df['mail'] = ''
    top_20_df = top_20_df.reset_index(drop=True)

    for prospect_id in range(len(top_20_df)):
        # Pause de 60s toutes les 10 requêtes
        if prospect_id > 0 and prospect_id % 10 == 0:
            print("Waiting 30 seconds to respect rate limits...")
            time.sleep(30)

        prospect = top_20_df.iloc[prospect_id]

        prompt = f"""
        Write a concise and professional cold email in English to offer your mission: {freelance['mission_statement']}
        to a company called {prospect['company']} based in {prospect['city']}, operating in the {prospect['sector']} sector.
        Your contact is {prospect['main_contact']}, who is the {prospect['contact_role']}.

        You are {freelance['name']}, a {freelance['title']} specialized in the {freelance['main_sector']} sector,
        based in {freelance['city']}. You offer services with top skills in {freelance['top3_skills']},
        at a daily rate of {freelance['daily_rate']} (remote: {freelance['remote']}).

        Highlight your main value proposition in 2–3 sentences, adapted to the needs of a company like {prospect['company']}
        (size: {prospect['company_size']}, funding stage: {prospect['funding_stage']}, remote work: {prospect['remote']}).

        Include a clear call to action. Keep the tone {freelance['preferred_tone']} and the style {freelance['preferred_style']},
        while matching the company’s target tone: {prospect['target_tone']}.
        """

        try:
            response = model.invoke(prompt)
            content = response.content if hasattr(response, "content") else str(response)
        except Exception as e:
            print(f"Error at index {prospect_id}: {e}")
            content = f"ERROR: {e}"

        top_20_df.at[prospect_id, 'mail'] = content

    return top_20_df

# %%
top_20 = mail_geneator(freelance, top_20_df)

# %%
top_20
# Out:
#                              company             sector      main_contact  \
# 0          Spencer, Jones and Miller          Tech/SaaS       Mark Romero
# 1       Joseph, Campbell and Douglas          Tech/SaaS     Tristan Rojas
# 2                        Perez-Smith          Tech/SaaS    Catherine Cole
# 3                       Thomas Group          Tech/SaaS  Alexander Taylor
# 4                   Rogers-Maldonado          Tech/SaaS       Ethan Allen
# 5                   Ramirez and Sons          Tech/SaaS     Marvin Robles
# 6                       Cortez-Olson          Marketing     Daniel Martin
# 7            Bennett, George and Fox          Marketing     Adrian Prince
# 8                         Lin-Mendez          Marketing         Mark Hill
# 9          Hayes, Elliott and George          Marketing     Michael Smith
# 10          Medina, Wise and Aguirre          Marketing    Ernest Jenkins
# 11                      Short-Parker          Tech/SaaS      Jared Carter
# 12        Warren, Flowers and Ingram          Tech/SaaS    Kenneth Harmon
# 13     Sanchez, Higgins and Caldwell          Tech/SaaS      Thomas Jones
# 14      Mcintyre, Molina and Collins          Tech/SaaS      Tracy Torres
# 15                   Brooks and Sons          Tech/SaaS      Alan Johnson
# 16                       Moyer-Patel          Tech/SaaS    Thomas Sellers
# 17                      Miller Group          Tech/SaaS     Monica Medina
# 18                      Rhodes-Gomez  Retail/E-commerce     Jeffrey Cooke
# 19  Christensen, Vasquez and Herrera  Retail/E-commerce     Candice Evans
#
#     contact_role                city  \
# 0   Head of Data      Lake Dianaland
# 1   Head of Data       North Melissa
# 2   Head of Data          East Renee
# 3   Head of Data         Patrickberg
# 4   Head of Data       Elizabethfurt
# 5   Head of Data       Lake Virginia
# 6   Head of Data          Johnsonton
# 7   Head of Data  South Vanessaville
# 8   Head of Data        Martinezport
# 9   Head of Data       New Davidtown
# 10  Head of Data        North Xavier
# 11           CTO  East Jennifershire
# 12           CTO        Caitlynmouth
# 13           CTO          Robertfurt
# 14           CTO        East Tiffany
# 15           CTO       West Loriland
# 16           CTO          Davidmouth
# 17           CTO          Sarahhaven
# 18  Head of Data         Natashastad
# 19  Head of Data          Robertland
#
#                                     mission_statement         company_size  \
# 0   Empowering effective digital transformation, i...         SME (21-200)
# 1   Empowering effective digital transformation, i...  Mid-size (201-1000)
# 2   Empowering effective digital transformation, i...   Enterprise (1000+)
# 3   Empowering effective digital transformation, i...         SME (21-200)
# 4   Empowering effective digital transformation, i...       Startup (1-20)
# 5   Empowering effective digital transformation, i...       Startup (1-20)
# 6   Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 7   Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 8   Delivering effective marketing strategies to i...         SME (21-200)
# 9   Delivering effective marketing strategies to i...         SME (21-200)
# 10  Delivering effective marketing strategies to i...  Mid-size (201-1000)
# 11  Empowering effective digital transformation, i...  Mid-size (201-1000)
# 12  Empowering effective digital transformation, i...       Startup (1-20)
# 13  Empowering effective digital transformation, i...       Startup (1-20)
# 14  Empowering effective digital transformation, i...   Enterprise (1000+)
# 15  Empowering effective digital transformation, i...       Startup (1-20)
# 16  Empowering effective digital transformation, i...   Enterprise (1000+)
# 17  Empowering effective digital transformation, i...   Enterprise (1000+)
# 18  Providing effective e-commerce solutions to in...   Enterprise (1000+)
# 19  Providing effective e-commerce solutions to in...       Startup (1-20)
#
#    funding_stage ticket_size_class   target_tone remote  similarity  \
# 0           Seed            Medium       Serious     No    0.310670
# 1           Seed            Medium      Creative    Yes    0.310670
# 2       Series B              High  Professional     No    0.310670
# 3           Seed            Medium       Serious    Yes    0.310670
# 4       Series A            Medium  Professional    Yes    0.310670
# 5           Seed               Low      Creative    Yes    0.310670
# 6      Series C+              High       Serious    Yes    0.276999
# 7       Series A            Medium      Friendly     No    0.276999
# 8       Series A            Medium      Creative    Yes    0.276999
# 9       Series B              High  Professional    Yes    0.276999
# 10      Series B              High       Serious    Yes    0.276999
# 11     Series C+              High      Friendly     No    0.276390
# 12     Series C+              High      Creative    Yes    0.276390
# 13      Series B              High  Professional    Yes    0.276390
# 14     Series C+              High  Professional     No    0.276390
# 15      Series B              High      Friendly     No    0.276390
# 16      Series B              High     Energetic     No    0.276390
# 17          Seed              High       Serious    Yes    0.276390
# 18      Series B              High  Professional     No    0.267038
# 19      Series B              High      Friendly    Yes    0.267038
#
#                                                  mail
# 0   Subject: Optimizing Spencer, Jones & Miller's ...
# 1   Subject: Level Up Joseph, Campbell & Douglas's...
# 2   Subject: Innovating Perez-Smith's Marketing wi...
# 3   Subject: Data-Driven Growth for Thomas Group: ...
# 4   Subject: Innovating Rogers-Maldonado's Growth ...
# 5   Subject: Level Up Ramirez & Sons' Growth with ...
# 6   Subject: Innovating Cortez-Olson's Marketing w...
# 7   Subject: Innovating Bennett, George and Fox's ...
# 8   Subject: Innovating Lin-Mendez's Marketing wit...
# 9   Subject: Innovating Hayes, Elliott and George'...
# 10  Subject: Optimizing Marketing Performance at M...
# 11  Subject: Innovating Short-Parker's Growth with...
# 12  Subject: Innovating Warren, Flowers and Ingram...
# 13  Subject: Innovating Sanchez, Higgins & Caldwel...
# 14  Subject: Innovating McIntyre, Molina and Colli...
# 15  Subject: Boosting Brooks & Sons' Growth with D...
# 16  Subject: Innovate Moyer-Patel's Marketing with...
# 17  Subject: Innovating Miller Group's Marketing w...
# 18  Subject: Transforming Rhodes-Gomez Retail with...
# 19  Subject: Innovating Christensen, Vasquez and H...

# %%
Markdown(top_20.iloc[4]['mail'])
# Out:
# Subject: Innovating Rogers-Maldonado's Growth with Data-Driven Marketing
#
# Dear Ethan Allen,
#
# As Head of Data at Rogers-Maldonado, you're likely focused on leveraging data to fuel growth. I'm Allison Hill, a digital marketing specialist based in East Jill, and I help Tech/SaaS companies like yours translate data into actionable strategies for impactful results. I specialize in using Analytics and Google Ads to optimize marketing spend and drive user acquisition, which can be particularly valuable during your Series A funding stage.
#
# Having worked with startups navigating similar growth phases, I understand the need for scalable, user-focused marketing. I believe my expertise in Analytics, Google Ads, and SEO can help Rogers-Maldonado unlock its full potential.
#
# Would you be open to a brief 15-minute call to discuss how I can help you optimize your marketing strategy?
#
# Sincerely,
#
# Allison Hill
# Digital Marketing Specialist
# (Remote: Yes, Daily Rate: 397.68)
