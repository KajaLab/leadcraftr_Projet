# %% [markdown]
# # 💞 Vectorisation & Matching

# %%
# Imports principaux
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
freelance_df = pd.read_csv('../generate_datasets/updated_freelances_dataset.csv', index_col='freelance_id').reset_index(drop=True)
prospect_df = pd.read_csv('../generate_datasets/updated_prospects_dataset.csv', index_col='prospect_id').reset_index(drop=True)
freelance_df
# Out:
#                 name                          title        main_sector  \
# 0       Allison Hill              Digital Marketing          Marketing
# 1     Javier Johnson     Renewable Energy Expertise          GreenTech
# 2    Meredith Barnes  Environmental Impact Analysis          GreenTech
# 3       Donald Lewis        Supply Chain Management  Retail/E-commerce
# 4        Renee Blair               Customer Service  Retail/E-commerce
# ..               ...                            ...                ...
# 295     Tracy Rivera             Project Management          GreenTech
# 296    Kristin Watts            Ed-Tech Integration  Education/Ed-Tech
# 297   Kathryn Cooper               Customer Service  Retail/E-commerce
# 298      Eric Gibson           Community Management           Wellness
# 299       Jodi Jones            Ed-Tech Integration  Education/Ed-Tech
#
#                                       top3_skills                 city  \
# 0                        Analytics|Google Ads|SEO            East Jill
# 1          LCA|Project Management|Energy Modeling         East William
# 2                         Energy Modeling|IoT|LCA         Lawrencetown
# 3    Facebook Ads|Customer Support|Data Analytics           Curtisfurt
# 4           Supply-Chain|Shopify|Customer Support  South Christianport
# ..                                            ...                  ...
# 295         Energy Modeling|IoT|Carbon Accounting       Rodriguezville
# 296         Learning Analytics|Storyline360|HTML5           South Neil
# 297      Data Analytics|Supply-Chain|Facebook Ads     South Danchester
# 298                 Copywriting|Pilates|Nutrition          New Timothy
# 299        Storyline360|Python|Learning Analytics    Port Jennifertown
#
#      daily_rate                                  mission_statement  \
# 0        397.68  Allison Hill delivers strategic strategies usi...
# 1        462.86  Javier Johnson drives analytical eco-solutions...
# 2        831.17  Meredith Barnes advances eco-friendly sustaina...
# 3        371.55  Donald Lewis boosts imaginative e-commerce wit...
# 4        621.60  Partner with Renee Blair for customer-focused ...
# ..          ...                                                ...
# 295      847.87  With Tracy Rivera's bold approach to Energy Mo...
# 296      374.88  Partner with Kristin Watts for engaging Learni...
# 297      534.32  Kathryn Cooper creates exclusive shopping expe...
# 298      519.93  Eric Gibson creates visionary wellness program...
# 299      496.21  Partner with Jodi Jones for innovative Storyli...
#
#     preferred_tone preferred_style remote  \
# 0     Professional    Storytelling    Yes
# 1          Serious          Formal    Yes
# 2         Friendly    Storytelling     No
# 3         Creative          Formal     No
# 4     Professional            Warm    Yes
# ..             ...             ...    ...
# 295      Energetic            Warm    Yes
# 296      Energetic          Formal     No
# 297        Premium    Storytelling    Yes
# 298       Creative            Warm     No
# 299       Creative            Warm    Yes
#
#                                            email
# 0            allison.hill@marketingfreelance.com
# 1          javier.johnson@greentechfreelance.com
# 2         meredith.barnes@greentechfreelance.com
# 3      donald.lewis@retailecommercefreelance.com
# 4       renee.blair@retailecommercefreelance.com
# ..                                           ...
# 295          tracy.rivera@greentechfreelance.com
# 296   kristin.watts@educationedtechfreelance.com
# 297  kathryn.cooper@retailecommercefreelance.com
# 298            eric.gibson@wellnessfreelance.com
# 299      jodi.jones@educationedtechfreelance.com
#
# [300 rows x 11 columns]

# %%
prospect_df
# Out:
#                             company             sector      main_contact  \
# 0            Marsh, Spears and Yang            FinTech    Kristen Rivera
# 1                         Lopez Ltd            FinTech      Allen Mendez
# 2                       Ramirez Ltd             Design        Amy Garcia
# 3          Huffman, Rose and Fowler          GreenTech     Lisa Matthews
# 4     Mcbride, Sellers and Lawrence          GreenTech       Emily Allen
# ...                             ...                ...               ...
# 2995                       Hill PLC  Retail/E-commerce       Amanda Bird
# 2996       Mendoza, Hayes and Lynch  Retail/E-commerce  Timothy Alvarado
# 2997   Carpenter, Nielsen and Stone          Tech/SaaS  Elaine Rodriguez
# 2998                      Wells Ltd          Marketing       Renee Hurst
# 2999        Garcia, Flores and Ford  Education/Ed-Tech       David Hines
#
#            contact_role                city  \
# 0                   CEO          Mullenbury
# 1                   CEO      South Brittany
# 2     Head of Marketing           West Mark
# 3          Head of Data        Michaelmouth
# 4                   CEO  East Nathanielberg
# ...                 ...                 ...
# 2995                CEO        Fergusonport
# 2996                CEO          Andrewfort
# 2997                CTO          Burchmouth
# 2998                CTO         Stanleyland
# 2999       Head of Data   North Josephmouth
#
#                                       mission_statement         company_size  \
# 0     sme rely on our intelligent FinTech services t...         SME (21-200)
# 1     At the heart of our mission: transform digital...   Enterprise (1000+)
# 2     Helping mid-size redefine storytelling brand s...  Mid-size (201-1000)
# 3     enterprise partner with us to accelerate susta...   Enterprise (1000+)
# 4     Our impact-driven solutions help enterprise pi...   Enterprise (1000+)
# ...                                                 ...                  ...
# 2995  We support startup in transform conversion rat...       Startup (1-20)
# 2996  Bringing retail online: our conversion-driven ...  Mid-size (201-1000)
# 2997  Scaling success: our resilient software empowe...         SME (21-200)
# 2998  Helping startup optimise brand storytelling br...       Startup (1-20)
# 2999  enterprise rely on our agile FinTech services ...   Enterprise (1000+)
#
#      funding_stage ticket_size_class target_tone remote  \
# 0        Series C+              High     Premium     No
# 1         Series A              High    Creative     No
# 2             Seed            Medium     Premium    Yes
# 3         Pre-Seed              High     Serious     No
# 4        Series C+              High   Energetic    Yes
# ...            ...               ...         ...    ...
# 2995      Series B              High    Friendly     No
# 2996          Seed            Medium    Friendly    Yes
# 2997      Series B              High     Premium    Yes
# 2998      Series B              High     Premium    Yes
# 2999          Seed              High   Energetic    Yes
#
#                                               email
# 0             kristen.rivera@marshspearsandyang.com
# 1                         allen.mendez@lopezltd.com
# 2                         amy.garcia@ramirezltd.com
# 3            lisa.matthews@huffmanroseandfowler.com
# 4         emily.allen@mcbridesellersandlawrence.com
# ...                                             ...
# 2995                        amanda.bird@hillplc.com
# 2996      timothy.alvarado@mendozahayesandlynch.com
# 2997  elaine.rodriguez@carpenternielsenandstone.com
# 2998                       renee.hurst@wellsltd.com
# 2999            david.hines@garciafloresandford.com
#
# [3000 rows x 12 columns]

# %%
def vectorize_missions(freelance_df, prospect_df):
    """Vectorise les mission statements des freelances et prospects avec TF-IDF."""
    vectorizer = TfidfVectorizer(stop_words='english')
    freelance_tfidf = vectorizer.fit_transform(freelance_df["mission_statement"])
    prospect_tfidf = vectorizer.transform(prospect_df["mission_statement"])
    return freelance_tfidf, prospect_tfidf

def get_top_20_leads(freelance_vec, prospect_tfidf, prospect_df):
    """
    Retourne les 20 prospects les plus similaires pour un vecteur freelance donné.

    Args:
        freelance_vec: Vecteur TF-IDF (1D ou 2D) du freelance (shape: (1, n_features)).
        prospect_tfidf: Matrice TF-IDF des prospects.
        prospect_df: DataFrame des prospects.

    Returns:
        DataFrame des 20 prospects les plus similaires avec score de similarité.
    """
    similarities = cosine_similarity(freelance_vec, prospect_tfidf).flatten()
    top_20_indices = similarities.argsort()[-20:][::-1]

    return prospect_df.iloc[top_20_indices].assign(
        similarity=similarities[top_20_indices]
    )

# %%
freelance_tfidf, prospect_tfidf = vectorize_missions(freelance_df, prospect_df)
top_20_df = get_top_20_leads(freelance_tfidf[0], prospect_tfidf, prospect_df)

# %%
top_20_df
# Out:
#                             company     sector        main_contact  \
# 558                    Anderson Inc     Design        Corey Thomas
# 2634  Walker, Alexander and Stevens     Design        Taylor Smith
# 1595                   Sharp-Wagner     Design     Elizabeth Smith
# 193                     Parsons PLC     Design          Cody Smith
# 1392     Martinez, Hudson and Munoz     Design       Lawrence Bass
# 2642                   Clark-Parker  Marketing      Madison Garcia
# 1855                   Jacobs Group  Marketing  Stephen Williamson
# 1107                      King-Rice  Marketing     Suzanne Rodgers
# 673                      Holden LLC  Marketing       Shannon Clark
# 931                    Cooper-Quinn  Marketing      Sabrina Miller
# 164                      Wilson Inc  Marketing         Mary Austin
# 1115                 Chandler-Roman     Design          Ann Dawson
# 1844       Day, Donaldson and Nunez     Design        Justin Mejia
# 804                  Elliott-Reeves  Marketing        Mike Bradley
# 1169     Juarez, Bowen and Randolph  Marketing          Tony Price
# 361                       Young Inc     Design       Emily Collier
# 2533                Jackson-Holland     Design       Denise Decker
# 2141                   Williams PLC  Marketing           Eric Cole
# 595                  Porter-Edwards  Marketing      Henry Anderson
# 61                      Evans-Davis  Marketing        Joshua Henry
#
#            contact_role               city  \
# 558        Head of Data       New Jameston
# 2634       Head of Data          New Debra
# 1595       Head of Data      Chaneychester
# 193   Head of Marketing       Kimberlybury
# 1392  Head of Marketing        Joshuamouth
# 2642       Head of Data        Jenniferton
# 1855       Head of Data     South Ericfort
# 1107                CEO         Connieview
# 673                 CEO        Palmerburgh
# 931        Head of Data          Smithland
# 164   Head of Marketing  Port Timothymouth
# 1115  Head of Marketing           Foxville
# 1844  Head of Marketing      North Jeffrey
# 804                 CEO        Thomasmouth
# 1169                CEO       South Sophia
# 361   Head of Marketing        Shafferbury
# 2533  Head of Marketing        Edwardsbury
# 2141  Head of Marketing          Emilystad
# 595   Head of Marketing  West Richardhaven
# 61                  CEO      West Adamland
#
#                                       mission_statement         company_size  \
# 558   Shaping how sme are perceived by elevate brand...         SME (21-200)
# 2634  Shaping how enterprise are perceived by elevat...   Enterprise (1000+)
# 1595  Shaping how mid-size are perceived by elevate ...  Mid-size (201-1000)
# 193   Shaping how startup are perceived by elevate b...       Startup (1-20)
# 1392  Shaping how sme are perceived by elevate brand...         SME (21-200)
# 2642  From insight to impact: we help enterprise opt...   Enterprise (1000+)
# 1855  We optimise brand storytelling brand presence ...       Startup (1-20)
# 1107  From insight to impact: we help mid-size pione...  Mid-size (201-1000)
# 673   From insight to impact: we help mid-size pione...  Mid-size (201-1000)
# 931   mid-size grow their reach by optimise brand st...  Mid-size (201-1000)
# 164   From insight to impact: we help startup optimi...       Startup (1-20)
# 1115  Shaping how enterprise are perceived by elevat...   Enterprise (1000+)
# 1844  Shaping how enterprise are perceived by elevat...   Enterprise (1000+)
# 804   Our strategic strategies enable startup to pio...       Startup (1-20)
# 1169  Our strategic strategies enable sme to pioneer...         SME (21-200)
# 361   Helping mid-size elevate brand aesthetics bran...  Mid-size (201-1000)
# 2533  Helping enterprise elevate brand aesthetics br...   Enterprise (1000+)
# 2141  We optimise brand storytelling brand presence ...  Mid-size (201-1000)
# 595   We optimise brand storytelling brand presence ...         SME (21-200)
# 61    We pioneer brand presence for sme by mixing SE...         SME (21-200)
#
#      funding_stage ticket_size_class   target_tone remote  \
# 558       Series B              High      Creative    Yes
# 2634     Series C+              High  Professional    Yes
# 1595      Pre-Seed            Medium       Serious     No
# 193       Pre-Seed               Low     Energetic     No
# 1392      Series A            Medium      Creative    Yes
# 2642      Series B              High     Energetic    Yes
# 1855          Seed               Low       Serious     No
# 1107      Pre-Seed            Medium       Premium     No
# 673      Series C+              High     Energetic    Yes
# 931           Seed            Medium       Premium     No
# 164           Seed               Low      Creative     No
# 1115     Series C+              High  Professional     No
# 1844          Seed              High      Creative    Yes
# 804      Series C+              High       Serious     No
# 1169          Seed            Medium       Serious    Yes
# 361           Seed            Medium     Energetic     No
# 2533     Series C+              High      Friendly     No
# 2141     Series C+              High       Serious    Yes
# 595       Series B              High       Premium     No
# 61        Series B              High       Serious    Yes
#
#                                            email  similarity
# 558                 corey.thomas@andersoninc.com    0.498487
# 2634  taylor.smith@walkeralexanderandstevens.com    0.498487
# 1595             elizabeth.smith@sharpwagner.com    0.498487
# 193                    cody.smith@parsonsplc.com    0.434225
# 1392    lawrence.bass@martinezhudsonandmunoz.com    0.434225
# 2642              madison.garcia@clarkparker.com    0.427103
# 1855          stephen.williamson@jacobsgroup.com    0.375663
# 1107                suzanne.rodgers@kingrice.com    0.373402
# 673                  shannon.clark@holdenllc.com    0.373402
# 931               sabrina.miller@cooperquinn.com    0.371422
# 164                    mary.austin@wilsoninc.com    0.356205
# 1115                ann.dawson@chandlerroman.com    0.346083
# 1844       justin.mejia@daydonaldsonandnunez.com    0.346083
# 804               mike.bradley@elliottreeves.com    0.326362
# 1169       tony.price@juarezbowenandrandolph.com    0.326362
# 361                   emily.collier@younginc.com    0.317084
# 2533            denise.decker@jacksonholland.com    0.317084
# 2141                   eric.cole@williamsplc.com    0.316855
# 595             henry.anderson@porteredwards.com    0.316855
# 61                   joshua.henry@evansdavis.com    0.316540

# %% [markdown]
# # 📧 Mail generator

# %%
from langchain.chat_models import init_chat_model
from IPython.display import Markdown
import time

# %%
def mail_generator(freelance, prospect):
    """
    Génère un email de prospection personnalisé en anglais à partir des données d’un freelance et d’une entreprise cible.

    Paramètres :
    -----------
    freelance : dict
        Dictionnaire contenant les informations du freelance :
        - 'name' : Nom complet
        - 'title' : Titre ou métier
        - 'main_sector' : Secteur principal d’activité
        - 'city' : Ville
        - 'top3_skills' : Compétences clés (format texte)
        - 'daily_rate' : Tarif journalier
        - 'remote' : "Yes"/"No"
        - 'mission_statement' : Résumé de la proposition de valeur
        - 'preferred_tone' : Ton préféré (ex. : Professional)
        - 'preferred_style' : Style préféré (ex. : Storytelling)

    prospect : pandas.Series ou dict
        Informations sur l’entreprise cible :
        - 'company' : Nom de l’entreprise
        - 'city' : Ville
        - 'sector' : Secteur d’activité
        - 'main_contact' : Nom du contact principal
        - 'contact_role' : Poste du contact
        - 'company_size' : Taille de l’entreprise
        - 'funding_stage' : Stade de financement
        - 'remote' : "Yes"/"No"
        - 'target_tone' : Ton attendu côté entreprise

    Retour :
    --------
    prospect : pandas.Series ou dict
        Le même objet que `prospect` mais avec un champ supplémentaire 'mail' contenant l’email généré.
    """

    model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")
    prospect = prospect.copy()

    prompt = f"""
    Write a clear, professional, and personalized cold email in English, addressed to {prospect['main_contact']} ({prospect['contact_role']})
    from the company {prospect['company']}, based in {prospect['city']} and operating in the {prospect['sector']} sector.

    You are {freelance['name']}, a {freelance['title']} based in {freelance['city']}, specialized in the {freelance['main_sector']} sector.
    You provide services with expertise in {freelance['top3_skills']}, at a daily rate of {freelance['daily_rate']} EUR (remote: {freelance['remote']}).
    Your mission is: {freelance['mission_statement']}

    The company is a {prospect['company_size']} at the {prospect['funding_stage']} stage, and remote work availability is {prospect['remote']}.

    The email should:
    - Open with a brief and relevant introduction.
    - Present the value you can bring to this company in 2–3 concise sentences.
    - Match the company's tone: {prospect['target_tone']}, while reflecting your preferred tone: {freelance['preferred_tone']} and style: {freelance['preferred_style']}.
    - Be business-oriented and adapted to the company's context.
    - End with a clear, actionable closing (e.g., propose a short call or ask for availability).
    - Sign with your name
    Ensure the language is polite, direct, and free from repetition or generic phrases. Avoid using placeholders or uncertain formulations.
    Return only the body of the email (no subject line or explanation).
    """

    try:
        response = model.invoke(prompt)
        content = response.content if hasattr(response, "content") else str(response)
    except Exception as e:
        print(f"Error : {e}")
        content = f"ERROR: {e}"

    prospect['mail'] = response.__dict__['content']

    return prospect

# %%
freelance_index = 2
freelance = freelance_df.iloc[freelance_index]
top_20_df = get_top_20_leads(freelance_tfidf[freelance_index], prospect_tfidf, prospect_df)
prospect = top_20_df.iloc[5]

prospect_mail = mail_generator(freelance, prospect)
Markdown(prospect_mail['mail'])
# Out:
# Hi Shannon,
#
# I came across Deleon-Herrera’s work in GreenTech and was particularly impressed by [mention a specific project or initiative]. It’s inspiring to see companies so dedicated to sustainable solutions.
#
# As an Environmental Impact Analyst specializing in Energy Modeling, IoT, and LCA, I help GreenTech companies like yours optimize their environmental impact and ensure long-term sustainability. I can deliver tailored strategies and impactful results, making sure your innovative technologies truly lead the way in eco-friendly practices.
#
# Would you be open to a brief 15-minute call next week to explore how my expertise could support Deleon-Herrera's goals?
#
# Best regards,
#
# Meredith Barnes
