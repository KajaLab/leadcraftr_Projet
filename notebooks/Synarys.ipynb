# %% [markdown]
# # 💞 Vectorisation & Matching

# %%
# Imports principaux
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
freelance_df = pd.read_csv('../generate_datasets/updated_freelances_dataset.csv', index_col='freelance_id').reset_index(drop=True)
prospect_df = pd.read_csv('../generate_datasets/updated_prospects_dataset.csv', index_col='prospect_id').reset_index(drop=True)
freelance_df
# Out:
#                 name                          title        main_sector  \
# 0       Allison Hill              Digital Marketing          Marketing
# 1     Javier Johnson     Renewable Energy Expertise          GreenTech
# 2    Meredith Barnes  Environmental Impact Analysis          GreenTech
# 3       Donald Lewis        Supply Chain Management  Retail/E-commerce
# 4        Renee Blair               Customer Service  Retail/E-commerce
# ..               ...                            ...                ...
# 295     Tracy Rivera             Project Management          GreenTech
# 296    Kristin Watts            Ed-Tech Integration  Education/Ed-Tech
# 297   Kathryn Cooper               Customer Service  Retail/E-commerce
# 298      Eric Gibson           Community Management           Wellness
# 299       Jodi Jones            Ed-Tech Integration  Education/Ed-Tech
#
#                                       top3_skills                 city  \
# 0                        Analytics|Google Ads|SEO            East Jill
# 1          LCA|Project Management|Energy Modeling         East William
# 2                         Energy Modeling|IoT|LCA         Lawrencetown
# 3    Facebook Ads|Customer Support|Data Analytics           Curtisfurt
# 4           Supply-Chain|Shopify|Customer Support  South Christianport
# ..                                            ...                  ...
# 295         Energy Modeling|IoT|Carbon Accounting       Rodriguezville
# 296         Learning Analytics|Storyline360|HTML5           South Neil
# 297      Data Analytics|Supply-Chain|Facebook Ads     South Danchester
# 298                 Copywriting|Pilates|Nutrition          New Timothy
# 299        Storyline360|Python|Learning Analytics    Port Jennifertown
#
#      daily_rate                                  mission_statement  \
# 0        397.68  Allison Hill delivers reliable strategies usin...
# 1        462.86  Javier Johnson advances focused sustainability...
# 2        831.17  Partner with Meredith Barnes for collaborative...
# 3        371.55  Donald Lewis boosts imaginative e-commerce wit...
# 4        621.60  Renee Blair creates strategic shopping experie...
# ..          ...                                                ...
# 295      847.87  Tracy Rivera promotes passionate GreenTech wit...
# 296      374.88  With Kristin Watts, motivational expertise in ...
# 297      534.32  Kathryn Cooper drives premium growth with Data...
# 298      519.93  With Eric Gibson's innovative approach to Copy...
# 299      496.21  With Jodi Jones, innovative expertise in Story...
#
#     preferred_tone preferred_style remote
# 0     Professional    Storytelling    Yes
# 1          Serious          Formal    Yes
# 2         Friendly    Storytelling     No
# 3         Creative          Formal     No
# 4     Professional            Warm    Yes
# ..             ...             ...    ...
# 295      Energetic            Warm    Yes
# 296      Energetic          Formal     No
# 297        Premium    Storytelling    Yes
# 298       Creative            Warm     No
# 299       Creative            Warm    Yes
#
# [300 rows x 10 columns]

# %%
prospect_df
# Out:
#                             company             sector      main_contact  \
# 0            Marsh, Spears and Yang            FinTech    Kristen Rivera
# 1                         Lopez Ltd            FinTech      Allen Mendez
# 2                       Ramirez Ltd             Design        Amy Garcia
# 3          Huffman, Rose and Fowler          GreenTech     Lisa Matthews
# 4     Mcbride, Sellers and Lawrence          GreenTech       Emily Allen
# ...                             ...                ...               ...
# 2995                       Hill PLC  Retail/E-commerce       Amanda Bird
# 2996       Mendoza, Hayes and Lynch  Retail/E-commerce  Timothy Alvarado
# 2997   Carpenter, Nielsen and Stone          Tech/SaaS  Elaine Rodriguez
# 2998                      Wells Ltd          Marketing       Renee Hurst
# 2999        Garcia, Flores and Ford  Education/Ed-Tech       David Hines
#
#            contact_role                city  \
# 0                   CEO          Mullenbury
# 1                   CEO      South Brittany
# 2     Head of Marketing           West Mark
# 3          Head of Data        Michaelmouth
# 4                   CEO  East Nathanielberg
# ...                 ...                 ...
# 2995                CEO        Fergusonport
# 2996                CEO          Andrewfort
# 2997                CTO          Burchmouth
# 2998                CTO         Stanleyland
# 2999       Head of Data   North Josephmouth
#
#                                       mission_statement         company_size  \
# 0     Transforming finance for sme through agile pla...         SME (21-200)
# 1     enterprise rely on our secure FinTech services...   Enterprise (1000+)
# 2     We streamline visual identity visual experienc...  Mid-size (201-1000)
# 3     Our resilient solutions help enterprise drive ...   Enterprise (1000+)
# 4     Our climate-conscious solutions help enterpris...   Enterprise (1000+)
# ...                                                 ...                  ...
# 2995  We support startup in pioneer conversion rates...       Startup (1-20)
# 2996  mid-size boost customer loyalty by pioneer pur...  Mid-size (201-1000)
# 2997  Scaling success: our modular software empowers...         SME (21-200)
# 2998  Our audience-focused strategies enable startup...       Startup (1-20)
# 2999  Bringing agile financial clarity to enterprise...   Enterprise (1000+)
#
#      funding_stage ticket_size_class target_tone remote
# 0        Series C+              High     Premium     No
# 1         Series A              High    Creative     No
# 2             Seed            Medium     Premium    Yes
# 3         Pre-Seed              High     Serious     No
# 4        Series C+              High   Energetic    Yes
# ...            ...               ...         ...    ...
# 2995      Series B              High    Friendly     No
# 2996          Seed            Medium    Friendly    Yes
# 2997      Series B              High     Premium    Yes
# 2998      Series B              High     Premium    Yes
# 2999          Seed              High   Energetic    Yes
#
# [3000 rows x 11 columns]

# %%
def vectorize_missions(freelance_df, prospect_df):
    """Vectorise les mission statements des freelances et prospects avec TF-IDF."""
    vectorizer = TfidfVectorizer(stop_words='english')
    freelance_tfidf = vectorizer.fit_transform(freelance_df["mission_statement"])
    prospect_tfidf = vectorizer.transform(prospect_df["mission_statement"])
    return freelance_tfidf, prospect_tfidf

def get_top_20_leads(freelance_vec, prospect_tfidf, prospect_df):
    """
    Retourne les 20 prospects les plus similaires pour un vecteur freelance donné.

    Args:
        freelance_vec: Vecteur TF-IDF (1D ou 2D) du freelance (shape: (1, n_features)).
        prospect_tfidf: Matrice TF-IDF des prospects.
        prospect_df: DataFrame des prospects.

    Returns:
        DataFrame des 20 prospects les plus similaires avec score de similarité.
    """
    similarities = cosine_similarity(freelance_vec, prospect_tfidf).flatten()
    top_20_indices = similarities.argsort()[-20:][::-1]

    return prospect_df.iloc[top_20_indices].assign(
        similarity=similarities[top_20_indices]
    )

# %%
freelance_tfidf, prospect_tfidf = vectorize_missions(freelance_df, prospect_df)
top_20_df = get_top_20_leads(freelance_tfidf[0], prospect_tfidf, prospect_df)

# %%
top_20_df
# Out:
#                                company     sector           main_contact  \
# 1181                         Solis LLC  Marketing           Laurie Johns
# 2079       Rivera, Fuller and Bradshaw  Marketing       Katherine Medina
# 1301        Murphy, Carter and Cochran  Marketing         Keith Mcdonald
# 588                        Smith Group  Marketing       Clarence Manning
# 2296                    Young and Sons  Marketing         Kevin Peterson
# 2235         Stone, Alvarado and Cross  Marketing  Dr. Jacqueline Martin
# 57                          Wright Inc  Marketing             Richard Le
# 1654                         Ellis PLC  Marketing          Lauren Morgan
# 1835                   Williams-Graves  Marketing        Robert Mcdowell
# 408                         Pham Group  Marketing        Stephanie Crane
# 892   Mccullough, Daniels and Davidson  Marketing      Kimberly Williams
# 755                         Forbes Ltd  Marketing           Mario Maddox
# 278                         Cook-Brown  Marketing      Deborah Alexander
# 1001                       Ramirez PLC  Marketing          Bethany Davis
# 1131          Morton, Kane and Douglas  Marketing           Maria Malone
# 211           Brooks, Todd and Farrell  Marketing           Anthony Rush
# 521          Bryant, Guzman and Thomas  Marketing         Rebecca Warner
# 101         Barber, Olson and Alvarado  Marketing       Brittany Serrano
# 2822                      Brown-Hanson  Marketing           Morgan Stone
# 2186                        Odom Group  Marketing         Ryan Hernandez
#
#       contact_role                 city  \
# 1181  Head of Data      East Davidville
# 2079  Head of Data          Sanfordland
# 1301  Head of Data        Port Meredith
# 588   Head of Data        Theodoremouth
# 2296  Head of Data            Evelynton
# 2235           CTO   South Kimberlytown
# 57    Head of Data  South Samuelchester
# 1654  Head of Data         Lake Deborah
# 1835  Head of Data     Lake Tinachester
# 408   Head of Data          Sherrymouth
# 892   Head of Data             Paulstad
# 755   Head of Data    Port Jenniferfort
# 278   Head of Data        Krauseborough
# 1001           CTO          Harrisshire
# 1131           CTO           Davishaven
# 211            CTO         Port Marissa
# 521   Head of Data            Kyleville
# 101            CTO      North Dawnburgh
# 2822           CTO        West Courtney
# 2186           CTO          Mahoneytown
#
#                                       mission_statement         company_size  \
# 1181  From insight to impact: we help enterprise opt...   Enterprise (1000+)
# 2079  Our disruptive strategies enable enterprise to...   Enterprise (1000+)
# 1301  Our disruptive strategies enable sme to optimi...         SME (21-200)
# 588   Our compelling strategies enable mid-size to o...  Mid-size (201-1000)
# 2296  Our disruptive strategies enable startup to op...       Startup (1-20)
# 2235  Our disruptive strategies enable enterprise to...   Enterprise (1000+)
# 57    We optimise brand storytelling brand presence ...         SME (21-200)
# 1654  From insight to impact: we help startup optimi...       Startup (1-20)
# 1835  From insight to impact: we help enterprise opt...   Enterprise (1000+)
# 408   From insight to impact: we help startup optimi...       Startup (1-20)
# 892   From insight to impact: we help mid-size optim...  Mid-size (201-1000)
# 755   From insight to impact: we help enterprise opt...   Enterprise (1000+)
# 278   sme grow their reach by optimise brand storyte...         SME (21-200)
# 1001  We optimise brand storytelling brand presence ...         SME (21-200)
# 1131  We optimise brand storytelling brand presence ...   Enterprise (1000+)
# 211   From insight to impact: we help mid-size optim...  Mid-size (201-1000)
# 521   Our audience-focused strategies enable enterpr...   Enterprise (1000+)
# 101   sme grow their reach by optimise brand storyte...         SME (21-200)
# 2822  enterprise grow their reach by optimise brand ...   Enterprise (1000+)
# 2186  startup grow their reach by optimise brand sto...       Startup (1-20)
#
#      funding_stage ticket_size_class   target_tone remote  similarity
# 1181          Seed              High       Premium     No    0.304745
# 2079      Pre-Seed              High       Serious     No    0.268355
# 1301      Series A            Medium      Friendly     No    0.268355
# 588       Series B              High  Professional    Yes    0.268355
# 2296     Series C+              High       Serious     No    0.268355
# 2235          Seed              High       Premium    Yes    0.253364
# 57        Pre-Seed            Medium     Energetic     No    0.250232
# 1654      Series B              High       Premium    Yes    0.249807
# 1835      Pre-Seed              High  Professional     No    0.249807
# 408      Series C+              High       Premium     No    0.249807
# 892       Pre-Seed            Medium       Premium    Yes    0.245241
# 755       Series B              High     Energetic     No    0.245241
# 278       Series A            Medium      Creative     No    0.227320
# 1001      Pre-Seed            Medium       Premium    Yes    0.223396
# 1131      Series B              High  Professional    Yes    0.223396
# 211       Series A            Medium  Professional     No    0.222580
# 521       Series A              High      Creative    Yes    0.222239
# 101       Series B              High  Professional     No    0.218244
# 2822      Pre-Seed              High       Premium    Yes    0.218244
# 2186     Series C+              High      Creative     No    0.218244

# %% [markdown]
# # 📧 Mail generator

# %%
from langchain.chat_models import init_chat_model
from IPython.display import Markdown
import time

# %%
def mail_generator(freelance, prospect):
    """
    Génère un email de prospection personnalisé en anglais à partir des données d’un freelance et d’une entreprise cible.

    Paramètres :
    -----------
    freelance : dict
        Dictionnaire contenant les informations du freelance :
        - 'name' : Nom complet
        - 'title' : Titre ou métier
        - 'main_sector' : Secteur principal d’activité
        - 'city' : Ville
        - 'top3_skills' : Compétences clés (format texte)
        - 'daily_rate' : Tarif journalier
        - 'remote' : "Yes"/"No"
        - 'mission_statement' : Résumé de la proposition de valeur
        - 'preferred_tone' : Ton préféré (ex. : Professional)
        - 'preferred_style' : Style préféré (ex. : Storytelling)

    prospect : pandas.Series ou dict
        Informations sur l’entreprise cible :
        - 'company' : Nom de l’entreprise
        - 'city' : Ville
        - 'sector' : Secteur d’activité
        - 'main_contact' : Nom du contact principal
        - 'contact_role' : Poste du contact
        - 'company_size' : Taille de l’entreprise
        - 'funding_stage' : Stade de financement
        - 'remote' : "Yes"/"No"
        - 'target_tone' : Ton attendu côté entreprise

    Retour :
    --------
    prospect : pandas.Series ou dict
        Le même objet que `prospect` mais avec un champ supplémentaire 'mail' contenant l’email généré.
    """

    model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")
    prospect = prospect.copy()

    prompt = f"""
    Write a clear, professional, and personalized cold email in English, addressed to {prospect['main_contact']} ({prospect['contact_role']})
    from the company {prospect['company']}, based in {prospect['city']} and operating in the {prospect['sector']} sector.

    You are {freelance['name']}, a {freelance['title']} based in {freelance['city']}, specialized in the {freelance['main_sector']} sector.
    You provide services with expertise in {freelance['top3_skills']}, at a daily rate of {freelance['daily_rate']} EUR (remote: {freelance['remote']}).
    Your mission is: {freelance['mission_statement']}

    The company is a {prospect['company_size']} at the {prospect['funding_stage']} stage, and remote work availability is {prospect['remote']}.

    The email should:
    - Open with a brief and relevant introduction.
    - Present the value you can bring to this company in 2–3 concise sentences.
    - Match the company's tone: {prospect['target_tone']}, while reflecting your preferred tone: {freelance['preferred_tone']} and style: {freelance['preferred_style']}.
    - Be business-oriented and adapted to the company's context.
    - End with a clear, actionable closing (e.g., propose a short call or ask for availability).
    - Sign with your name
    Ensure the language is polite, direct, and free from repetition or generic phrases. Avoid using placeholders or uncertain formulations.
    Return only the body of the email (no subject line or explanation).
    """

    try:
        response = model.invoke(prompt)
        content = response.content if hasattr(response, "content") else str(response)
    except Exception as e:
        print(f"Error : {e}")
        content = f"ERROR: {e}"

    prospect['mail'] = response.__dict__['content']

    return prospect

# %%
freelance_index = 2
freelance = freelance_df.iloc[freelance_index]
top_20_df = get_top_20_leads(freelance_tfidf[freelance_index], prospect_tfidf, prospect_df)
prospect = top_20_df.iloc[5]

prospect_mail = mail_generator(freelance, prospect)
Markdown(prospect_mail['mail'])
# Out:
# Dear Latoya,
#
# I recently came across Poole PLC's work in Jacksonmouth, and I'm genuinely impressed by your commitment to GreenTech innovation. It feels like you're building a future where sustainability isn't just a buzzword, but a core principle.
#
# As an Environmental Impact Analyst specializing in Energy Modeling, IoT, and LCA, I believe I can help Poole PLC further refine its eco-impact strategies. Think of me as a translator, turning complex environmental data into actionable insights that drive innovation and efficiency – all within your existing infrastructure. Imagine being able to predict the environmental impact of your newest projects before they even leave the drawing board.
#
# Would you be open to a brief 15-minute call next week to explore how my expertise can specifically benefit Poole PLC?
#
# Sincerely,
#
# Meredith Barnes
