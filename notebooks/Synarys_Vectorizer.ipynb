# %% [markdown]
# # 🧠 LeadCraftr - Vectorisation & Matching

# %%
# Imports principaux
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
freelance_df = pd.read_csv('../generate_datasets/freelances_dataset.csv', index_col='freelance_id')
prospect_df = pd.read_csv('../generate_datasets/prospects_dataset.csv', index_col='freelance_id')
freelance_df
# Out:
#                                    nom                                titre  \
# freelance_id
# 1                     Alexandre Traore         Marketing digital (SEO, SEM)
# 2                  Aurore Maury-Briand                  Stratégie de marque
# 3                       Édouard Rocher        Gestion de cloud (AWS, Azure)
# 4                       Julie Bertrand                   Gestion de produit
# 5                     Alphonse Peltier         Marketing digital (SEO, SEM)
# ...                                ...                                  ...
# 296                      Georges Klein          Connaissance des normes ESG
# 297             Gabriel-Auguste Renaud  Développement de systèmes sécurisés
# 298                    Suzanne Bouvier  Développement de systèmes sécurisés
# 299           Charles-Benjamin Barbier  Développement de systèmes sécurisés
# 300                    Alexandre Lebon         Création de contenu wellness
#
#                secteur_principal                                 skills_top3  \
# freelance_id
# 1                      Marketing                    Analytics|Google Ads|SEO
# 2                      Marketing             Copywriting|SEO|Email Marketing
# 3                      Tech/SaaS                     Docker|PostgreSQL|CI/CD
# 4                      Tech/SaaS                           FastAPI|CI/CD|AWS
# 5                      Marketing                  Copywriting|SEO|Google Ads
# ...                          ...                                         ...
# 296                    GreenTech       Energy Modeling|Carbon Accounting|LCA
# 297                      FinTech                          SQL|Python|AML/KYC
# 298                      FinTech                   SQL|PowerBI|Risk Modeling
# 299                      FinTech                          Python|PowerBI|SQL
# 300           Wellness/Bien-Être  Copywriting|Community Management|Nutrition
#
#                           ville     tjm  \
# freelance_id
# 1                        Moulin  397.68
# 2                    Saint Éric  365.59
# 3              Leblanc-la-Forêt  454.31
# 4                  RegnierBourg  494.51
# 5                         Leleu  893.25
# ...                         ...     ...
# 296                       Gomes  622.44
# 297                     Valette  836.24
# 298                Mathieuboeuf  718.45
# 299                     Fischer  677.83
# 300           Berthelot-sur-Mer  718.54
#
#                                       mission_statement tonalite_preferee  \
# freelance_id
# 1                     Le confort d'avancer à l'état pur     Professionnel
# 2                  L'avantage d'innover de manière sûre      Bienveillant
# 3                       Le pouvoir d'avancer avant-tout           Sérieux
# 4                     L'avantage de changer à sa source      Bienveillant
# 5                    Le pouvoir d'innover naturellement           Sérieux
# ...                                                 ...               ...
# 296                        L'art de louer naturellement      Bienveillant
# 297                Le confort d'avancer plus facilement     Professionnel
# 298                    Le droit d'innover naturellement           Premium
# 299           La liberté d'innover en toute tranquilité     Professionnel
# 300                  Le droit d'avancer de manière sûre           Premium
#
#              style_prefere
# freelance_id
# 1             Storytelling
# 2             Storytelling
# 3               Chaleureux
# 4               Chaleureux
# 5               Chaleureux
# ...                    ...
# 296             Chaleureux
# 297                 Formel
# 298                 Formel
# 299                 Formel
# 300             Chaleureux
#
# [300 rows x 9 columns]

# %%
prospect_df
# Out:
#       prospect_id              societe             secteur  \
# 0               1   Rivière Richard SA             FinTech
# 1               2              Sanchez  Wellness/Bien-Être
# 2               3             Pinto SA           GreenTech
# 3               4               Benoit           GreenTech
# 4               5               Didier  Wellness/Bien-Être
# ...           ...                  ...                 ...
# 2995         2996               Baudry           GreenTech
# 2996         2997  Ledoux Lejeune S.A.   Retail/E-commerce
# 2997         2998             Ollivier   Éducation/Ed-Tech
# 2998         2999       Diallo Ruiz SA              Design
# 2999         3000                Marin             FinTech
#
#                  contact_principal       role_contact                   ville  \
# 0     Christophe Philippe-Maréchal                CTO                  Torres
# 1                  Arthur Philippe                CTO          RodriguezBourg
# 2                 Sébastien Lesage  Head of Marketing               MaheVille
# 3                  Guillaume Guyot       Head of Data             GérardVille
# 4                 Valentine Bonnet       Head of Data  Sainte Alice-les-Bains
# ...                            ...                ...                     ...
# 2995         Émile-Auguste Loiseau                CEO                  Didier
# 2996                Maggie Verdier  Head of Marketing              Schmittdan
# 2997              Mathilde Duhamel       Head of Data                   Alves
# 2998            Joséphine Valentin                CTO    Sainte MatthieuVille
# 2999             Étienne Bourgeois  Head of Marketing      Seguin-sur-Richard
#
#                             mission_statement    company_size funding_stage  \
# 0           Whiteboard strategic applications  ETI (201-1000)          Seed
# 1          Productize open-source initiatives  ETI (201-1000)      Pre-Seed
# 2                  Synergize cutting-edge roi  Groupe (1000+)      Pre-Seed
# 3     Re-intermediate interactive experiences  ETI (201-1000)      Series B
# 4                   Deploy 24/365 experiences  Groupe (1000+)          Seed
# ...                                       ...             ...           ...
# 2995                Maximize 24/365 platforms     PME (21-200      Series A
# 2996      Strategize plug-and-play e-commerce     PME (21-200     Series C+
# 2997       Generate cutting-edge partnerships     PME (21-200      Series A
# 2998                      Engage seamless roi  Groupe (1000+)     Series C+
# 2999             Innovate holistic interfaces  ETI (201-1000)     Series C+
#
#      ticket_size_class tonalite_cible
# 0               Medium        Créatif
# 1               Medium        Premium
# 2                 High        Premium
# 3                 High   Bienveillant
# 4                 High   Bienveillant
# ...                ...            ...
# 2995            Medium        Premium
# 2996              High        Premium
# 2997            Medium   Bienveillant
# 2998              High        Premium
# 2999              High  Professionnel
#
# [3000 rows x 11 columns]

# %%
# TF-IDF vectorisation des missions
vectorizer = TfidfVectorizer(stop_words='english')
freelance_tfidf = vectorizer.fit_transform(freelance_df["mission_statement"])
prospect_tfidf = vectorizer.transform(prospect_df["mission_statement"])

# %%
# Fonction pour récupérer les 20 meilleurs prospects pour un freelance donné
def top_20_leads_for_freelance(freelance_index):
    freelance_vec = freelance_tfidf[freelance_index]
    similarities = cosine_similarity(freelance_vec, prospect_tfidf).flatten()
    top_20_indices = similarities.argsort()[-20:][::-1]
    return prospect_df.loc[top_20_indices].assign(
        similarity=similarities[top_20_indices],
        freelance_id=freelance_index
    )
