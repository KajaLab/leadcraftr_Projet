# %% [markdown]
# # 🧠 LeadCraftr - Vectorisation & Matching

# %%
# Imports principaux
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
freelance_df = pd.read_csv('../generate_datasets/freelances_dataset.csv', index_col='freelance_id').reset_index()
prospect_df = pd.read_csv('../generate_datasets/prospects_dataset.csv', index_col='prospect_id').reset_index()
freelance_df
# Out:
#      freelance_id                       nom  \
# 0               1          Alexandre Traore
# 1               2       Aurore Maury-Briand
# 2               3            Édouard Rocher
# 3               4            Julie Bertrand
# 4               5          Alphonse Peltier
# ..            ...                       ...
# 295           296             Georges Klein
# 296           297    Gabriel-Auguste Renaud
# 297           298           Suzanne Bouvier
# 298           299  Charles-Benjamin Barbier
# 299           300           Alexandre Lebon
#
#                                    titre   secteur_principal  \
# 0           Marketing digital (SEO, SEM)           Marketing
# 1                    Stratégie de marque           Marketing
# 2          Gestion de cloud (AWS, Azure)           Tech/SaaS
# 3                     Gestion de produit           Tech/SaaS
# 4           Marketing digital (SEO, SEM)           Marketing
# ..                                   ...                 ...
# 295          Connaissance des normes ESG           GreenTech
# 296  Développement de systèmes sécurisés             FinTech
# 297  Développement de systèmes sécurisés             FinTech
# 298  Développement de systèmes sécurisés             FinTech
# 299         Création de contenu wellness  Wellness/Bien-Être
#
#                                     skills_top3              ville     tjm  \
# 0                      Analytics|Google Ads|SEO             Moulin  397.68
# 1               Copywriting|SEO|Email Marketing         Saint Éric  365.59
# 2                       Docker|PostgreSQL|CI/CD   Leblanc-la-Forêt  454.31
# 3                             FastAPI|CI/CD|AWS       RegnierBourg  494.51
# 4                    Copywriting|SEO|Google Ads              Leleu  893.25
# ..                                          ...                ...     ...
# 295       Energy Modeling|Carbon Accounting|LCA              Gomes  622.44
# 296                          SQL|Python|AML/KYC            Valette  836.24
# 297                   SQL|PowerBI|Risk Modeling       Mathieuboeuf  718.45
# 298                          Python|PowerBI|SQL            Fischer  677.83
# 299  Copywriting|Community Management|Nutrition  Berthelot-sur-Mer  718.54
#
#                              mission_statement tonalite_preferee style_prefere
# 0            Le confort d'avancer à l'état pur     Professionnel  Storytelling
# 1         L'avantage d'innover de manière sûre      Bienveillant  Storytelling
# 2              Le pouvoir d'avancer avant-tout           Sérieux    Chaleureux
# 3            L'avantage de changer à sa source      Bienveillant    Chaleureux
# 4           Le pouvoir d'innover naturellement           Sérieux    Chaleureux
# ..                                         ...               ...           ...
# 295               L'art de louer naturellement      Bienveillant    Chaleureux
# 296       Le confort d'avancer plus facilement     Professionnel        Formel
# 297           Le droit d'innover naturellement           Premium        Formel
# 298  La liberté d'innover en toute tranquilité     Professionnel        Formel
# 299         Le droit d'avancer de manière sûre           Premium    Chaleureux
#
# [300 rows x 10 columns]

# %%
prospect_df
# Out:
#       prospect_id              societe             secteur  \
# 0               1   Rivière Richard SA             FinTech
# 1               2              Sanchez  Wellness/Bien-Être
# 2               3             Pinto SA           GreenTech
# 3               4               Benoit           GreenTech
# 4               5               Didier  Wellness/Bien-Être
# ...           ...                  ...                 ...
# 2995         2996               Baudry           GreenTech
# 2996         2997  Ledoux Lejeune S.A.   Retail/E-commerce
# 2997         2998             Ollivier   Éducation/Ed-Tech
# 2998         2999       Diallo Ruiz SA              Design
# 2999         3000                Marin             FinTech
#
#                  contact_principal       role_contact                   ville  \
# 0     Christophe Philippe-Maréchal                CTO                  Torres
# 1                  Arthur Philippe                CTO          RodriguezBourg
# 2                 Sébastien Lesage  Head of Marketing               MaheVille
# 3                  Guillaume Guyot       Head of Data             GérardVille
# 4                 Valentine Bonnet       Head of Data  Sainte Alice-les-Bains
# ...                            ...                ...                     ...
# 2995         Émile-Auguste Loiseau                CEO                  Didier
# 2996                Maggie Verdier  Head of Marketing              Schmittdan
# 2997              Mathilde Duhamel       Head of Data                   Alves
# 2998            Joséphine Valentin                CTO    Sainte MatthieuVille
# 2999             Étienne Bourgeois  Head of Marketing      Seguin-sur-Richard
#
#                             mission_statement    company_size funding_stage  \
# 0           Whiteboard strategic applications  ETI (201-1000)          Seed
# 1          Productize open-source initiatives  ETI (201-1000)      Pre-Seed
# 2                  Synergize cutting-edge roi  Groupe (1000+)      Pre-Seed
# 3     Re-intermediate interactive experiences  ETI (201-1000)      Series B
# 4                   Deploy 24/365 experiences  Groupe (1000+)          Seed
# ...                                       ...             ...           ...
# 2995                Maximize 24/365 platforms     PME (21-200      Series A
# 2996      Strategize plug-and-play e-commerce     PME (21-200     Series C+
# 2997       Generate cutting-edge partnerships     PME (21-200      Series A
# 2998                      Engage seamless roi  Groupe (1000+)     Series C+
# 2999             Innovate holistic interfaces  ETI (201-1000)     Series C+
#
#      ticket_size_class tonalite_cible
# 0               Medium        Créatif
# 1               Medium        Premium
# 2                 High        Premium
# 3                 High   Bienveillant
# 4                 High   Bienveillant
# ...                ...            ...
# 2995            Medium        Premium
# 2996              High        Premium
# 2997            Medium   Bienveillant
# 2998              High        Premium
# 2999              High  Professionnel
#
# [3000 rows x 11 columns]

# %%
def vectorize_missions(freelance_df, prospect_df):
    """Vectorise les mission statements des freelances et prospects avec TF-IDF."""
    vectorizer = TfidfVectorizer(stop_words='english')
    freelance_tfidf = vectorizer.fit_transform(freelance_df["mission_statement"])
    prospect_tfidf = vectorizer.transform(prospect_df["mission_statement"])
    return freelance_tfidf, prospect_tfidf

def get_top_20_leads(freelance_vec, prospect_tfidf, prospect_df):
    """
    Retourne les 20 prospects les plus similaires pour un vecteur freelance donné.

    Args:
        freelance_vec: Vecteur TF-IDF (1D ou 2D) du freelance (shape: (1, n_features)).
        prospect_tfidf: Matrice TF-IDF des prospects.
        prospect_df: DataFrame des prospects.

    Returns:
        DataFrame des 20 prospects les plus similaires avec score de similarité.
    """
    similarities = cosine_similarity(freelance_vec, prospect_tfidf).flatten()
    top_20_indices = similarities.argsort()[-20:][::-1]

    return prospect_df.iloc[top_20_indices].assign(
        similarity=similarities[top_20_indices]
    )

# %%
freelance_tfidf, prospect_tfidf = vectorize_missions(freelance_df, prospect_df)
top_20_df = get_top_20_leads(freelance_tfidf[0], prospect_tfidf, prospect_df)

# %%
top_20_df
# Out:
#       prospect_id               societe             secteur  \
# 0               1    Rivière Richard SA             FinTech
# 2999         3000                 Marin             FinTech
# 2998         2999        Diallo Ruiz SA              Design
# 2997         2998              Ollivier   Éducation/Ed-Tech
# 2996         2997   Ledoux Lejeune S.A.   Retail/E-commerce
# 2995         2996                Baudry           GreenTech
# 2994         2995             Toussaint             FinTech
# 2993         2994  Bigot Pascal et Fils             FinTech
# 2992         2993                Lesage              Design
# 2991         2992               Guibert           GreenTech
# 2990         2991                Delmas   Retail/E-commerce
# 2989         2990  Philippe Dubois SARL           Marketing
# 2988         2989                Ledoux   Retail/E-commerce
# 2987         2988  Torres Imbert S.A.S.  Wellness/Bien-Être
# 2986         2987              Maréchal              Design
# 2985         2986               Georges           Tech/SaaS
# 2984         2985  Charpentier S.A.R.L.              Design
# 2983         2984   Lemaire Renard S.A.              Design
# 2982         2983                Nguyen           Marketing
# 2981         2982               Vincent   Éducation/Ed-Tech
#
#                  contact_principal       role_contact                 ville  \
# 0     Christophe Philippe-Maréchal                CTO                Torres
# 2999             Étienne Bourgeois  Head of Marketing    Seguin-sur-Richard
# 2998            Joséphine Valentin                CTO  Sainte MatthieuVille
# 2997              Mathilde Duhamel       Head of Data                 Alves
# 2996                Maggie Verdier  Head of Marketing            Schmittdan
# 2995         Émile-Auguste Loiseau                CEO                Didier
# 2994           Brigitte de Lagarde                CEO        Petitjeanboeuf
# 2993                   Noël Boulay  Head of Marketing      Sainte Gabrielle
# 2992               Capucine Brunet  Head of Marketing                Arnaud
# 2991          François-Jean Dijoux       Head of Data               Delorme
# 2990           Alexandria Maillard  Head of Marketing        Benard-sur-Mer
# 2989              Philippine Colas                CTO                 Dupré
# 2988             Christiane Launay                CEO                 Neveu
# 2987                  Charles Blin       Head of Data                Gaudin
# 2986                Adrien Maillet                CEO     Hoareau-les-Bains
# 2985              Joséphine Robert                CEO        Moreau-sur-Mer
# 2984          Zacharie de Langlois                CTO         Carpentiernec
# 2983                Gabriel Marion       Head of Data                 Aubry
# 2982        Pierre Rodriguez-Marin       Head of Data               Guillon
# 2981              Bertrand Poulain                CEO      Maury-sur-Brunet
#
#                         mission_statement    company_size funding_stage  \
# 0       Whiteboard strategic applications  ETI (201-1000)          Seed
# 2999         Innovate holistic interfaces  ETI (201-1000)     Series C+
# 2998                  Engage seamless roi  Groupe (1000+)     Series C+
# 2997   Generate cutting-edge partnerships     PME (21-200      Series A
# 2996  Strategize plug-and-play e-commerce     PME (21-200     Series C+
# 2995            Maximize 24/365 platforms     PME (21-200      Series A
# 2994  Benchmark cross-media relationships     PME (21-200     Series C+
# 2993       Unleash magnetic architectures     PME (21-200     Series C+
# 2992      Embrace proactive architectures  ETI (201-1000)     Series C+
# 2991        Matrix e-business initiatives  Groupe (1000+)     Series C+
# 2990            Transform viral solutions  ETI (201-1000)      Series A
# 2989           Engineer robust interfaces     PME (21-200      Series A
# 2988              Generate killer metrics  Groupe (1000+)     Series C+
# 2987   Deploy frictionless info-mediaries  Startup (1-20)      Series A
# 2986             Leverage b2c initiatives     PME (21-200      Series A
# 2985      Strategize integrated e-markets  ETI (201-1000)     Series C+
# 2984         Engage plug-and-play content     PME (21-200      Series A
# 2983         Engage revolutionary systems  Groupe (1000+)     Series C+
# 2982    Cultivate revolutionary e-tailers  Groupe (1000+)      Series B
# 2981         Synthesize dot-com e-tailers  ETI (201-1000)      Series B
#
#      ticket_size_class tonalite_cible  similarity
# 0               Medium        Créatif         0.0
# 2999              High  Professionnel         0.0
# 2998              High        Premium         0.0
# 2997            Medium   Bienveillant         0.0
# 2996              High        Premium         0.0
# 2995            Medium        Premium         0.0
# 2994              High      Énergique         0.0
# 2993              High        Créatif         0.0
# 2992              High   Bienveillant         0.0
# 2991              High   Bienveillant         0.0
# 2990            Medium   Bienveillant         0.0
# 2989            Medium        Premium         0.0
# 2988              High  Professionnel         0.0
# 2987            Medium        Créatif         0.0
# 2986            Medium        Premium         0.0
# 2985              High        Créatif         0.0
# 2984            Medium        Créatif         0.0
# 2983              High        Premium         0.0
# 2982              High        Créatif         0.0
# 2981              High        Sérieux         0.0
